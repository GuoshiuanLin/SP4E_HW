# %% [markdown]
# ## Using the GMRES we developed and plotting the results

# %%
# %run Exc2.py --matrix_A 8 1 1 3 --nrows_A 2 --vector_b 2 4 --minimizer "GMRES_custom" --plot
# Out:
# optimization by BFGS: (0.08695651393909959, 1.3043478215741857, -2.695652173913043)
# optimization by GMRES: (0.08695652173913082, 1.304347826086957, -2.6956521739130435)
# Exercise 2
# ___
# A is:
#  [[8. 1.]
#  [1. 3.]]
# b is:
#  [2. 4.]
# Selected method is the custom GMRes, ...
# Iteration 1: Residual Norm = 2.0606629773070586
# Iteration 2: Residual Norm = 1.971075837763094e-14
# Solution is [0.08695652 1.30434783]

# %% [markdown]
# ## Without plot

# %%
# %run Exc2.py --matrix_A 8 1 1 3 --nrows_A 2 --vector_b 2 4 --minimizer "GMRES_custom"
# Out:
# Exercise 2
# ___
# A is:
#  [[8. 1.]
#  [1. 3.]]
# b is:
#  [2. 4.]
# Selected method is the custom GMRes, ...
# Iteration 1: Residual Norm = 2.0606629773070586
# Iteration 2: Residual Norm = 1.971075837763094e-14
# Solution is [0.08695652 1.30434783]
# Plotting is disabled.

# %% [markdown]
# ## Using the GMRES from scipy and plotting the results

# %%
# %run Exc2.py --matrix_A 8 1 1 3 --nrows_A 2 --vector_b 2 4 --minimizer "GMRES" --plot
# Out:
# Exercise 2
# ___
# A is:
#  [[8. 1.]
#  [1. 3.]]
# b is:
#  [2. 4.]
# Selected method is  GMRES
# Solution is (0.08695652173913082, 1.304347826086957)
# c:\Users\glin\OneDrive - epfl.ch\SciProgramming\Homwork1\Exc2.py:56: DeprecationWarning: scipy.sparse.linalg.lgmres called without specifying `atol`. The default value will change in the future. To preserve current behavior, set ``atol=tol``.
#   result = linalg.lgmres(A, b, [3,3], callback=callback_function)
