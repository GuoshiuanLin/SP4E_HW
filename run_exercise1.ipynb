# %%
# %run optimizer.py
# Out:
# optimization by BFGS: (0.08695693232010031, 1.3043445972403283, -2.6956521738980572)
# optimization by GMRES: (0.08695652173913127, 1.304347826086956, -2.6956521739130435)
# c:\Users\glin\OneDrive - epfl.ch\SciProgramming\Homwork1\optimizer.py:37: DeprecationWarning: scipy.sparse.linalg.lgmres called without specifying `atol`. The default value will change in the future. To preserve current behavior, set ``atol=tol``.
#   result = linalg.lgmres(A, b, [3,-3])

# %%
# %run plot.py
# Out:
# optimization by BFGS: (0.08695693232010031, 1.3043445972403283, -2.6956521738980572)
# optimization by GMRES: (0.08695652173913127, 1.304347826086956, -2.6956521739130435)
# c:\Users\glin\OneDrive - epfl.ch\SciProgramming\Homwork1\plot.py:48: DeprecationWarning: scipy.sparse.linalg.lgmres called without specifying `atol`. The default value will change in the future. To preserve current behavior, set ``atol=tol``.
#   result = linalg.lgmres(A, b, [3,-3], callback=callback_function)
